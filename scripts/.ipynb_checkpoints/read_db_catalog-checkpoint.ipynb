# %%
import databroker
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib widget

# %%
catalog = databroker.catalog['xpd-ldrd20-31']
# Out:
# WARNING:hdf5plugin:bshuf filter already loaded, skip it.
# WARNING:hdf5plugin:lz4 filter already loaded, skip it.

# %%
'''
RE(xray_uvvis_plan(det, qepro, num_fast=3, sample_type='quinine_1E-4M'))
'''
uid = '7adadc0c-3f07-4eba-95d5-77f6d3f639f9'

# %%
run = catalog[uid]
run
# Out:
# BlueskyRun
#   uid='7adadc0c-3f07-4eba-95d5-77f6d3f639f9'
#   exit_status='success'
#   2023-02-20 17:02:23.406 -- 2023-02-20 17:02:48.223
#   Streams:
#     * absorbance
#     * fluorescence
#     * scattering

# %%
fl = run.fluorescence.read()
fl
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 6, dim_0: 36, dim_1: 1044, dim_2: 1044, dim_3: 1044, dim_4: 1044, dim_5: 1044)
# Coordinates:
#   * time                            (time) float64 1.677e+09 ... 1.677e+09
# Dimensions without coordinates: dim_0, dim_1, dim_2, dim_3, dim_4, dim_5
# Data variables: (12/37)
#     QEPro_serial                    (time) <U8 'QEP02875' ... 'QEP02875'
#     QEPro_model                     (time) <U6 'QE-PRO' 'QE-PRO' ... 'QE-PRO'
#     QEPro_status                    (time) int64 0 0 0 0 0 0
#     QEPro_status_msg                (time, dim_0) int64 87 114 111 ... 109 46 0
#     QEPro_device_connected          (time) int64 1 1 1 1 1 1
#     QEPro__QEPro__check_status      (time) int64 0 0 0 0 0 0
#     ...                              ...
#     QEPro_ref_available             (time) int64 1 1 1 1 1 1
#     QEPro_acquire                   (time) int64 0 0 0 0 0 0
#     QEPro_collect_mode              (time) int64 1 1 1 1 1 1
#     QEPro_spectrum_type             (time) int64 2 2 2 2 2 2
#     QEPro_correction                (time) int64 1 1 1 1 1 1
#     QEPro_trigger_mode              (time) int64 0 0 0 0 0 0

# %%
fl.dims
fl['QEPro_output'].shape
# Out:
# (6, 1044)

# %%
plt.figure()
for i in range(fl['QEPro_output'].shape[0]):
    plt.plot(fl['QEPro_x_axis'][i], fl['QEPro_output'][i], label=i)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ab = run.absorbance.read()
ab
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 3, dim_0: 36, dim_1: 1044, dim_2: 1044, dim_3: 1044, dim_4: 1044, dim_5: 1044)
# Coordinates:
#   * time                            (time) float64 1.677e+09 1.677e+09 1.677e+09
# Dimensions without coordinates: dim_0, dim_1, dim_2, dim_3, dim_4, dim_5
# Data variables: (12/37)
#     QEPro_serial                    (time) <U8 'QEP02875' 'QEP02875' 'QEP02875'
#     QEPro_model                     (time) <U6 'QE-PRO' 'QE-PRO' 'QE-PRO'
#     QEPro_status                    (time) int64 0 0 0
#     QEPro_status_msg                (time, dim_0) int64 87 114 111 ... 109 46 0
#     QEPro_device_connected          (time) int64 1 1 1
#     QEPro__QEPro__check_status      (time) int64 0 0 0
#     ...                              ...
#     QEPro_ref_available             (time) int64 1 1 1
#     QEPro_acquire                   (time) int64 0 0 0
#     QEPro_collect_mode              (time) int64 1 1 1
#     QEPro_spectrum_type             (time) int64 3 3 3
#     QEPro_correction                (time) int64 2 2 2
#     QEPro_trigger_mode              (time) int64 0 0 0

# %%
ab.dims
ab['QEPro_output'].shape
# Out:
# (3, 1044)

# %%
plt.figure()
for i in range(ab['QEPro_output'].shape[0]):
    plt.plot(ab['QEPro_x_axis'][i], ab['QEPro_output'][i], label=i)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
